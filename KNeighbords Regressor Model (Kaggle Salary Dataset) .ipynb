# %% [markdown]
# Kaggle Model (salary dataset)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r"D:\Egaletly Solution ( AI )\Machine Learning\Salary_dataset.csv")

# %%
df.head(10)
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0
# 5           5              3.0  56643.0
# 6           6              3.1  60151.0
# 7           7              3.3  54446.0
# 8           8              3.3  64446.0
# 9           9              3.8  57190.0

# %%
df.shape
# Out:
# (30, 3)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# Unnamed: 0         0
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(x="YearsExperience",y="Salary",data=df,alpha=0.5,)
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X = df.drop(['Salary'], axis='columns')
y = df[['Salary']]

X_train, X_test, y_train, y_test = train_test_split(X, y,random_state=42, test_size=10,shuffle=True)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X.columns
# Out:
# Index(['Unnamed: 0', 'YearsExperience'], dtype='object')

# %%
X_train= pd.DataFrame(X_train_scaled,columns=X.columns)
X_test= pd.DataFrame(X_test_scaled,columns=X.columns)

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
krr= KNeighborsRegressor(n_neighbors=4)

# %%
krr.fit(X_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=4)

# %%
krr.score(X_train,y_train)*100
# Out:
# 96.36725625514848

# %%
krr.score(X_test,y_test)*100
# Out:
# 0.9606490670174785
