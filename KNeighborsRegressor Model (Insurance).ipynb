# %% [markdown]
# KNeighbors Regressor Model (Insurance)

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r"D:\Egaletly Solution ( AI )\Machine Learning\Insurance ( Data ).csv")

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# Check & Remove Duplicated values

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df = df.drop_duplicates()

# %% [markdown]
# Check Missing Values

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# Dividing the data into numerical and categorical

# %%
numerical = df.select_dtypes(exclude="O")

# %%
numerical
# Out:
#       age     bmi  children      charges
# 0      19  27.900         0  16884.92400
# 1      18  33.770         1   1725.55230
# 2      28  33.000         3   4449.46200
# 3      33  22.705         0  21984.47061
# 4      32  28.880         0   3866.85520
# ...   ...     ...       ...          ...
# 1333   50  30.970         3  10600.54830
# 1334   18  31.920         0   2205.98080
# 1335   18  36.850         0   1629.83350
# 1336   21  25.800         0   2007.94500
# 1337   61  29.070         0  29141.36030
#
# [1337 rows x 4 columns]

# %%
obj = df.select_dtypes(include="O")

# %%
obj
# Out:
#          sex smoker     region
# 0     female    yes  southwest
# 1       male     no  southeast
# 2       male     no  southeast
# 3       male     no  northwest
# 4       male     no  northwest
# ...      ...    ...        ...
# 1333    male     no  northwest
# 1334  female     no  northeast
# 1335  female     no  southeast
# 1336  female     no  southwest
# 1337  female    yes  northwest
#
# [1337 rows x 3 columns]

# %% [markdown]
# Encoding

# %%
en_data = df[["sex","smoker","region"]]

# %%
clean_obj = pd.get_dummies(en_data,dtype="int",drop_first="True")

# %%
clean_obj
# Out:
#       sex_male  smoker_yes  region_northwest  region_southeast  \
# 0            0           1                 0                 0
# 1            1           0                 0                 1
# 2            1           0                 0                 1
# 3            1           0                 1                 0
# 4            1           0                 1                 0
# ...        ...         ...               ...               ...
# 1333         1           0                 1                 0
# 1334         0           0                 0                 0
# 1335         0           0                 0                 1
# 1336         0           0                 0                 0
# 1337         0           1                 1                 0
#
#       region_southwest
# 0                    1
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 1333                 0
# ...

# %%
numerical
# Out:
#       age     bmi  children      charges
# 0      19  27.900         0  16884.92400
# 1      18  33.770         1   1725.55230
# 2      28  33.000         3   4449.46200
# 3      33  22.705         0  21984.47061
# 4      32  28.880         0   3866.85520
# ...   ...     ...       ...          ...
# 1333   50  30.970         3  10600.54830
# 1334   18  31.920         0   2205.98080
# 1335   18  36.850         0   1629.83350
# 1336   21  25.800         0   2007.94500
# 1337   61  29.070         0  29141.36030
#
# [1337 rows x 4 columns]

# %%
clean_obj["age"] = numerical["age"]

# %%
clean_obj["bmi"] = numerical["bmi"]

# %%
clean_obj["children"] = numerical["children"]

# %%
clean_obj["charges"] = numerical["charges"]

# %%
clean_obj
# Out:
#       sex_male  smoker_yes  region_northwest  region_southeast  \
# 0            0           1                 0                 0
# 1            1           0                 0                 1
# 2            1           0                 0                 1
# 3            1           0                 1                 0
# 4            1           0                 1                 0
# ...        ...         ...               ...               ...
# 1333         1           0                 1                 0
# 1334         0           0                 0                 0
# 1335         0           0                 0                 1
# 1336         0           0                 0                 0
# 1337         0           1                 1                 0
#
#       region_southwest  age     bmi  children      charges
# 0                    1   19  27.900         0  16884.92400
# 1                    0   18  33.770         1   1725.55230
# ...

# %% [markdown]
# Divide the data in training and testing

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X = clean_obj.drop(['charges'], axis='columns')
y = clean_obj[['charges']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,random_state = 42,test_size=50,shuffle=True)

# %%
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X.columns
# Out:
# Index(['sex_male', 'smoker_yes', 'region_northwest', 'region_southeast',
#        'region_southwest', 'age', 'bmi', 'children'],
#       dtype='object')

# %%
X_train= pd.DataFrame(X_train_scaled,columns=X.columns)
X_test= pd.DataFrame(X_test_scaled,columns=X.columns)

# %% [markdown]
# Build Model

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
krr= KNeighborsRegressor(n_neighbors=3)

# %%
krr.fit(X_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
krr.score(X_train,y_train)*100
# Out:
# 89.76017442827768

# %%
krr.score(X_test,y_test)*100
# Out:
# 86.85534860457524
