# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r"D:\Egaletly Solution ( AI )\Machine Learning\gender_classification_v7.csv")

# %%
df.head(3)
# Out:
#    long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0          1               11.8                 6.1          1          0
# 1          0               14.0                 5.4          0          0
# 2          0               11.8                 6.3          1          1
#
#    lips_thin  distance_nose_to_lip_long  gender
# 0          1                          1    Male
# 1          1                          0  Female
# 2          1                          1    Male

# %%
df.shape
# Out:
# (5001, 8)

# %%
df.duplicated().sum()
# Out:
# 1768

# %%
df.isna().sum()
# Out:
# long_hair                    0
# forehead_width_cm            0
# forehead_height_cm           0
# nose_wide                    0
# nose_long                    0
# lips_thin                    0
# distance_nose_to_lip_long    0
# gender                       0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
df.dtypes
# Out:
# long_hair                      int64
# forehead_width_cm            float64
# forehead_height_cm           float64
# nose_wide                      int64
# nose_long                      int64
# lips_thin                      int64
# distance_nose_to_lip_long      int64
# gender                        object
# dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop(['gender'], axis='columns')
y = df[['gender']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,shuffle=False)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X.columns
# Out:
# Index(['long_hair', 'forehead_width_cm', 'forehead_height_cm', 'nose_wide',
#        'nose_long', 'lips_thin', 'distance_nose_to_lip_long'],
#       dtype='object')

# %%
X_train= pd.DataFrame(X_train_scaled,columns=X.columns)
X_test= pd.DataFrame(X_test_scaled,columns=X.columns)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
neighbour= KNeighborsClassifier(n_neighbors=10)
neighbour.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
neighbour.score(X_train,y_train)*100
# Out:
# 95.59164733178655

# %%
neighbour.score(X_test,y_test)*100
# Out:
# 94.28129829984545
